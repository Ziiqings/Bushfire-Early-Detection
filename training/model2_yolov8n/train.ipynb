# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
model.train(
    data="training/data_preparing/data/wildfire/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    device=0,
    workers=8,
    seed=42
)
